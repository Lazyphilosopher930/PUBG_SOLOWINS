# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import mean_squared_error

# %%
player=pd.read_csv("PUBG_Player_Statistics.csv")

# %%
player.head()
# Out:
#      player_name  tracker_id  solo_KillDeathRatio  solo_WinRatio  \
# 0      BreakNeck        4405                 3.14          17.65
# 1      Blackwalk        8199                 4.41          18.18
# 2  mercedes_benz        4454                 3.60           0.00
# 3           DORA        7729                14.00          50.00
# 4        n2tstar           0                10.50          33.33
#
#    solo_TimeSurvived  solo_RoundsPlayed  solo_Wins  solo_WinTop10Ratio  \
# 0           18469.14                 17          3                0.83
# 1           33014.86                 33          6                0.36
# 2            4330.44                  5          0                0.00
# 3           13421.82                  8          4                0.67
# 4            9841.04                  6          2                0.40
#
#    solo_Top10s  solo_Top10Ratio     ...       squad_RideDistance  \
# 0            4             23.5     ...               3751590.99
# ...

# %%
player.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87898 entries, 0 to 87897
# Columns: 152 entries, player_name to squad_DBNOs
# dtypes: float64(83), int64(68), object(1)
# memory usage: 101.9+ MB

# %%
player.isnull().sum()
# Out:
# player_name                  0
# tracker_id                   0
# solo_KillDeathRatio          0
# solo_WinRatio                0
# solo_TimeSurvived            0
# solo_RoundsPlayed            0
# solo_Wins                    0
# solo_WinTop10Ratio           0
# solo_Top10s                  0
# solo_Top10Ratio              0
# solo_Losses                  0
# solo_Rating                  0
# solo_BestRating              0
# solo_DamagePg                0
# solo_HeadshotKillsPg         0
# solo_HealsPg                 0
# solo_KillsPg                 0
# solo_MoveDistancePg          0
# solo_RevivesPg               0
# solo_RoadKillsPg             0
# solo_TeamKillsPg             0
# solo_TimeSurvivedPg          0
# solo_Top10sPg                0
# solo_Kills                   0
# solo_Assists                 0
# solo_Suicides                0
# solo_TeamKills               0
# solo_HeadshotKills           0
# solo_HeadshotKillRatio       0
# solo_VehicleDestroys         0
# ...

# %%
feature=['solo_WinRatio','solo_KillDeathRatio','solo_TeamKills','solo_HeadshotKillRatio','solo_HeadshotKills','solo_Rating','solo_LongestKill','solo_DamagePg','solo_Boosts','solo_DamageDealt','solo_RoundsPlayed','solo_WinTop10Ratio','solo_Top10s','solo_Top10Ratio']
x=player[feature]
y=player.solo_Wins
print(x)
# Out:
#        solo_WinRatio  solo_KillDeathRatio  solo_TeamKills  \
# 0              17.65                 3.14               0
# 1              18.18                 4.41               0
# 2               0.00                 3.60               0
# 3              50.00                14.00               0
# 4              33.33                10.50               0
# 5              31.25                 5.73               0
# 6               8.45                 2.45               3
# 7              26.32                 2.71               0
# 8              13.64                 3.68               0
# 9              25.00                 4.17               0
# 10              6.03                 3.12               0
# 11              1.19                 1.20               3
# 12             10.34                 4.46               0
# 13              5.56                 2.60               1
# 14             13.04                 3.60               0
# ...

# %%
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.1)

# %%
linreg = LinearRegression()
linreg.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
linreg.score(x_test,y_test)
# Out:
# 0.8470560091351462
